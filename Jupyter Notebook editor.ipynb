# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Momodou Krubally**
#
# Desired Position: Data Scientist

# %% [markdown]
# I am interested in data science because I like working with data

# %% [markdown]
# ### This is a basic arithmetic

# %%
a = 2
b = 3
print(a*b)
# Out:
# 6

# %% [markdown]
# ### The forest and its inhabitants
#
# ![The Beautiful Forest](https://unsplash.com/photos/body-of-water-surrounded-by-pine-trees-during-daytime-ESkw2ayO2As)
#
#
# | Name | Gestation |
# | :---:| :--------:|
# | Bear | omnivores |
# | Elk  | vegetarian|
# | Snake| carnivores|
#
# ### Pets
#
# * Dogs
# * Cats
# * Snakes
#
# ### Types of trees
# 1. [White Ash]('http://bhort.bh.cornell.edu/tree/whiteash.htm')
# 1. [Yellow Birch]('http://bhort.bh.cornell.edu/tree/yellowbirch.htm')
